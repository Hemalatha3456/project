# %% [markdown]
# # Exploratory Data Analysis (EDA) Report

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cleaned_dataset.csv")
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
plt.hist(df["Marks"])
plt.title("Distribution of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
df.groupby("Department")["Marks"].mean().plot(kind="bar")
plt.title("Average Marks by Department")
plt.ylabel("Average Marks")
plt.show()

# %% [markdown]
# ## Conclusion
#
# - The dataset contains student information including marks and attendance.
# - There are no missing values.
# - The notebook demonstrates basic EDA steps.
# - The data is ready for further analysis or ML tasks.
